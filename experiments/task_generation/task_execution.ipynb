# %% [markdown]
# # Overview of Pre-Defined Tasks with *RTGL*

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def get_tables(task):
    print(task.get_table("train"))
    print(task.get_table("val"))
    print(task.get_table("test"))

# %% [markdown]
# ## ReDeLEx Datasets

# %% [markdown]
# ### Grants Dataset

# %%
from rtgl_tasks.tasks.redelex_tasks import AwardsInstitutionStatTask

get_tables(AwardsInstitutionStatTask())
# Out:
# SQL query executed in 0.09 seconds
# ------------------ Table ------------------
# DataFrame:
#             fk  label
# 153174  158242  10798
# 323592  333910   7321
# 177988  183948   1393
# 227694  235514   2375
# 202910  209940  15258
# ...        ...    ...
# 229372  237222  15342
# 88249    90903   6693
# 55694    57494   9302
# 291611  301100  15343
# 147039  151805   8867
#
# [333369 rows x 2 columns]
# Foreign Key Columns to Primary Key Tables: {'fk': 'awards'}
# Primary Key Column: None
# Time Column: None
# -------------------------------------------
# ------------------ Table ------------------
# DataFrame:
#             fk  label
# 172180  177930  10620
# 30080    31087   6682
# 267873  276739   5081
# 411556  424995  15386
# 256297  264829  15293
# ...        ...    ...
# 220606  228243  14133
# 160665  166010  15279
# 220928  228578  15169
# 300106  309818   7321
# 405932  419185  15217
#
# [41671 rows x 2 columns]
# ...

# %%
from rtgl_tasks.tasks.redelex_tasks import CountInstitutionAwardsStatTask

get_tables(CountInstitutionAwardsStatTask())
# Out:
# SQL query executed in 0.06 seconds
# ------------------ Table ------------------
# DataFrame:
#           fk  label
# 5852    5852      1
# 14558  14558      1
# 7044    7044      2
# 2683    2683      1
# 291      291     24
# ...      ...    ...
# 13582  13582      2
# 11048  11048      1
# 10053  10053      2
# 10851  10851      1
# 3384    3384     10
#
# [13353 rows x 2 columns]
# Foreign Key Columns to Primary Key Tables: {'fk': 'institution'}
# Primary Key Column: None
# Time Column: None
# -------------------------------------------
# ------------------ Table ------------------
# DataFrame:
#           fk  label
# 13621  13621      2
# 15062  15062      1
# 1633    1633      2
# 1331    1331      4
# 8135    8135      1
# ...      ...    ...
# 2079    2079      1
# 1252    1252      1
# 153      153      1
# 13042  13042      8
# 1382    1382      2
#
# [1669 rows x 2 columns]
# Foreign Key Columns to Primary Key Tables: {'fk': 'institution'}
# Primary Key Column: None
# ...

# %%
from rtgl_tasks.tasks.redelex_tasks import OrganizationAwardsAmountStatTask

get_tables(OrganizationAwardsAmountStatTask())
# Out:
# SQL query executed in 0.03 seconds
# ------------------ Table ------------------
# DataFrame:
#       fk         label
# 375  375  3.486535e+06
# 422  422  1.408279e+08
# 9      9  7.496286e+06
# 73    73  2.297054e+07
# 354  354  2.286982e+06
# ..   ...           ...
# 216  216  3.253000e+05
# 279  279  2.794530e+07
# 451  451  2.216656e+08
# 409  409  7.555105e+07
# 337  337  4.400150e+09
#
# [380 rows x 2 columns]
# Foreign Key Columns to Primary Key Tables: {'fk': 'organization'}
# Primary Key Column: None
# Time Column: None
# -------------------------------------------
# ------------------ Table ------------------
# DataFrame:
#       fk         label
# 160  160  8.355181e+07
# 71    71  6.597130e+05
# 43    43  5.037110e+05
# 166  166  1.291210e+05
# 106  106  1.757850e+06
# 102  102  1.699146e+08
# 434  434  1.517996e+06
# 80    80  1.075014e+09
# 151  151  7.540894e+08
# 464  464  9.542099e+07
# 264  264  1.558392e+06
# 315  315  9.308595e+08
# 270  270  1.624519e+07
# ...

# %% [markdown]
# ### Seznam Dataset

# %%
from rtgl_tasks.tasks.redelex_tasks import ClientOutOfWalletTmpTask

get_tables(ClientOutOfWalletTmpTask())
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# SQL query executed in 2.31 seconds
# ------------------ Table ------------------
# DataFrame:
#            fk  timestamp  label
# 0           4 2012-08-13   True
# 1           8 2012-08-13   True
# 2           9 2012-08-13   True
# 3          11 2012-08-13   True
# 4          13 2012-08-13   True
# ...       ...        ...    ...
# 787290  73396 2015-01-30  False
# 787291  73424 2015-01-30  False
# 787292  73429 2015-01-30  False
# 787293  73434 2015-01-30  False
# 787294  73442 2015-01-30  False
#
# [787295 rows x 3 columns]
# Foreign Key Columns to Primary Key Tables: {'fk': 'client'}
# Primary Key Column: None
# Time Column: timestamp
# -------------------------------------------
# SQL query executed in 0.38 seconds
# ------------------ Table ------------------
# DataFrame:
#            fk  timestamp  label
# 0           0 2015-03-01  False
# 1           1 2015-03-01  False
# ...

# %%
from rtgl_tasks.tasks.redelex_tasks import ClientServisTmpTask

get_tables(ClientServisTmpTask())
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# SQL query executed in 3.42 seconds
# ------------------ Table ------------------
# DataFrame:
#            fk  timestamp   label
# 0           0 2012-08-13     [d]
# 1           1 2012-08-13     [d]
# 2           2 2012-08-13     [d]
# 3           6 2012-08-13     [d]
# 4          17 2012-08-13     [e]
# ...       ...        ...     ...
# 832906  73437 2015-01-30     [h]
# 832907  73438 2015-01-30  [d, a]
# 832908  73439 2015-01-30     [e]
# 832909  73443 2015-01-30  [d, h]
# 832910  73444 2015-01-30  [h, d]
#
# [832911 rows x 3 columns]
# Foreign Key Columns to Primary Key Tables: {'fk': 'client'}
# Primary Key Column: None
# Time Column: timestamp
# -------------------------------------------
# SQL query executed in 0.46 seconds
# ------------------ Table ------------------
# DataFrame:
#           fk  timestamp      label
# 0          1 2015-03-31  [d, h, a]
# ...

# %%
from rtgl_tasks.tasks.redelex_tasks import ClientFirstServisTmpTask

get_tables(ClientFirstServisTmpTask())
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# SQL query executed in 4.55 seconds
# ------------------ Table ------------------
# DataFrame:
#            fk  timestamp label
# 0           0 2012-08-13     d
# 1           1 2012-08-13     d
# 2           2 2012-08-13     d
# 3           6 2012-08-13     d
# 4          17 2012-08-13     e
# ...       ...        ...   ...
# 831238  73437 2015-01-30     h
# 831239  73438 2015-01-30     d
# 831240  73439 2015-01-30     e
# 831241  73443 2015-01-30     h
# 831242  73444 2015-01-30     d
#
# [831243 rows x 3 columns]
# Foreign Key Columns to Primary Key Tables: {'fk': 'client'}
# Primary Key Column: None
# Time Column: timestamp
# -------------------------------------------
# SQL query executed in 0.57 seconds
# ------------------ Table ------------------
# DataFrame:
#           fk  timestamp label
# 0          1 2015-03-31     h
# 1          2 2015-03-31     d
# ...

# %%
from rtgl_tasks.tasks.redelex_tasks import ClientSpendingTmpTask

get_tables(ClientSpendingTmpTask())
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# SQL query executed in 2.22 seconds
# ------------------ Table ------------------
# DataFrame:
#             fk  timestamp     label
# 0            0 2012-08-13   5294.04
# 1            1 2012-08-13   5162.16
# 2            2 2012-08-13   2351.86
# 3            4 2012-08-13      0.00
# 4            6 2012-08-13  22987.94
# ...        ...        ...       ...
# 1631252  73438 2015-01-30  32517.84
# 1631253  73439 2015-01-30  25744.86
# 1631254  73442 2015-01-30      0.00
# 1631255  73443 2015-01-30   3290.72
# 1631256  73444 2015-01-30   2882.52
#
# [1631257 rows x 3 columns]
# Foreign Key Columns to Primary Key Tables: {'fk': 'client'}
# Primary Key Column: None
# Time Column: timestamp
# -------------------------------------------
# SQL query executed in 0.36 seconds
# ------------------ Table ------------------
# DataFrame:
#            fk  timestamp    label
# ...

# %% [markdown]
# ### SfScores Dataset

# %%
from rtgl_tasks.tasks.redelex_tasks import BusinessesScoresTmpTask

get_tables(BusinessesScoresTmpTask())
# Out:
# SQL query executed in 0.04 seconds
# ------------------ Table ------------------
# DataFrame:
#         fk  timestamp  label
# 0        0 2013-12-19     92
# 1        1 2013-12-19     96
# 2        4 2013-12-19     92
# 3        5 2013-12-19     92
# 4        6 2013-12-19    100
# ...    ...        ...    ...
# 7780  5913 2015-06-18     86
# 7781  5914 2015-06-18    100
# 7782  5929 2015-06-18     94
# 7783  5933 2015-06-18     74
# 7784  5949 2015-06-18     74
#
# [7785 rows x 3 columns]
# Foreign Key Columns to Primary Key Tables: {'fk': 'businesses'}
# Primary Key Column: None
# Time Column: timestamp
# -------------------------------------------
# SQL query executed in 0.04 seconds
# ------------------ Table ------------------
# DataFrame:
#         fk  timestamp  label
# 0        0 2015-12-17     82
# 1        1 2015-12-17     96
# 2        3 2015-12-17     84
# 3        6 2015-12-17     88
# 4        7 2015-12-17     73
# ...    ...        ...    ...
# ...

# %% [markdown]
# ### Stats Dataset

# %%
from rtgl_tasks.tasks.redelex_tasks import UserReputationStatTask

get_tables(UserReputationStatTask())
# Out:
# Validation completed with 2 semantic warning(s):
# /mnt/personal/kolesole/RTGL/rtgl_tasks/base/rtgl_stat_task.py:33: [WARN] Table 'comments' has multiple paths to parent table 'users'. Using the shortest one: comments.fk_users_userid -> users.__pk__
# /mnt/personal/kolesole/RTGL/rtgl_tasks/base/rtgl_stat_task.py:33: [WARN] Table 'votes' has multiple paths to parent table 'users'. Using the shortest one: votes.fk_users_userid -> users.__pk__
# SQL query executed in 0.08 seconds
# ------------------ Table ------------------
# DataFrame:
#           fk  label
# 15319  23201      6
# 24517  40236      8
# 23316  37841      1
# 3494    5278  37083
# 11216  16777      8
# ...      ...    ...
# 3791    5756     11
# 23034  37279      1
# 14154  21390    106
# 2786    4221     26
# 9259   13796      8
#
# [19649 rows x 2 columns]
# Foreign Key Columns to Primary Key Tables: {'fk': 'users'}
# Primary Key Column: None
# Time Column: None
# -------------------------------------------
# ...

# %%
from rtgl_tasks.tasks.redelex_tasks import PostTagsStatTask

get_tables(PostTagsStatTask())
# Out:
# SQL query executed in 0.05 seconds
# ------------------ Table ------------------
# DataFrame:
#         fk  label
# 188  34218  [481]
# 238  40656  [772]
# 462  56273  [868]
# 465  56346    [9]
# 182  33730  [126]
# ..     ...    ...
# 397  53887   [10]
# 254  43397  [791]
# 217  37518  [518]
# 4     2815   [32]
# 256  43666  [736]
#
# [477 rows x 2 columns]
# Foreign Key Columns to Primary Key Tables: {'fk': 'posts', 'label': 'tags'}
# Primary Key Column: None
# Time Column: None
# -------------------------------------------
# ------------------ Table ------------------
# DataFrame:
#         fk   label
# 590  88196  [1003]
# 476  59116   [602]
# 308  51074   [818]
# 121  25836   [339]
# 567  75159   [375]
# 252  42662   [171]
# 448  56090   [480]
# 543  66164   [694]
# 413  54969    [81]
# 510  65092    [78]
# 454  56114   [580]
# 13    7740   [369]
# 292  50578    [40]
# 138  28645   [139]
# 466  56358   [226]
# 458  56159   [841]
# 391  53469   [218]
# 230  39594   [766]
# ...

# %%
from rtgl_tasks.tasks.redelex_tasks import UserBadgeStatTask

get_tables(UserBadgeStatTask())
# Out:
# SQL query executed in 0.04 seconds
# ------------------ Table ------------------
# DataFrame:
#           fk  label
# 13638  13638      2
# 23193  23193      6
# 26776  26776      0
# 15413  15413      1
# 28966  28966      1
# ...      ...    ...
# 22030  22030      5
# 11595  11595      0
# 27578  27578      0
# 18205  18205      0
# 1312    1312     12
#
# [32260 rows x 2 columns]
# Foreign Key Columns to Primary Key Tables: {'fk': 'users'}
# Primary Key Column: None
# Time Column: None
# -------------------------------------------
# ------------------ Table ------------------
# DataFrame:
#           fk  label
# 39516  39516      1
# 13897  13897      0
# 29863  29863      0
# 9120    9120      3
# 2491    2491      0
# ...      ...    ...
# 15379  15379      1
# 4583    4583      2
# 32154  32154      1
# 4655    4655      0
# 8055    8055      3
#
# [4032 rows x 2 columns]
# Foreign Key Columns to Primary Key Tables: {'fk': 'users'}
# Primary Key Column: None
# ...

# %%
from rtgl_tasks.tasks.redelex_tasks import UserEngagementStatTask

get_tables(UserEngagementStatTask())
# Out:
# Validation completed with 2 semantic warning(s):
# /mnt/personal/kolesole/RTGL/rtgl_tasks/base/rtgl_stat_task.py:33: [WARN] Table 'comments' has multiple paths to parent table 'users'. Using the shortest one: comments.fk_users_userid -> users.__pk__
# /mnt/personal/kolesole/RTGL/rtgl_tasks/base/rtgl_stat_task.py:33: [WARN] Table 'votes' has multiple paths to parent table 'users'. Using the shortest one: votes.fk_users_userid -> users.__pk__
# SQL query executed in 0.08 seconds
# ------------------ Table ------------------
# DataFrame:
#           fk  label
# 13638  13638   True
# 23193  23193   True
# 26776  26776  False
# 15413  15413   True
# 28966  28966  False
# ...      ...    ...
# 22030  22030   True
# 11595  11595  False
# 27578  27578   True
# 18205  18205   True
# 1312    1312   True
#
# [32260 rows x 2 columns]
# Foreign Key Columns to Primary Key Tables: {'fk': 'users'}
# Primary Key Column: None
# Time Column: None
# -------------------------------------------
# ...

# %%
from rtgl_tasks.tasks.redelex_tasks import PostVotesStatTask

get_tables(PostVotesStatTask())
# Out:
# Validation completed with 1 semantic warning(s):
# /mnt/personal/kolesole/RTGL/rtgl_tasks/base/rtgl_stat_task.py:33: [WARN] Table 'votes' has multiple paths to parent table 'posts'. Using the shortest one: votes.fk_posts_postid -> posts.__pk__
# SQL query executed in 0.10 seconds
# ------------------ Table ------------------
# DataFrame:
#           fk  label
# 35582  79890      2
# 19327  48173      5
# 37347  83066      0
# 11762  32073      0
# 3548   11811      8
# ...      ...    ...
# 37201  82804      0
# 19797  49114      2
# 34427  77758      0
# 36143  80926      0
# 17290  43975      1
#
# [33750 rows x 2 columns]
# Foreign Key Columns to Primary Key Tables: {'fk': 'posts'}
# Primary Key Column: None
# Time Column: None
# -------------------------------------------
# ------------------ Table ------------------
# DataFrame:
#           fk  label
# 22852  55701      1
# 34872  78573      0
# 23474  57048      0
# 15524  40267      3
# 20541  50655      0
# ...

# %%
from rtgl_tasks.tasks.redelex_tasks import UserPostCommentStatTask

get_tables(UserPostCommentStatTask())
# Out:
# Validation completed with 2 semantic warning(s):
# /mnt/personal/kolesole/RTGL/rtgl_tasks/base/rtgl_stat_task.py:33: [WARN] Table 'comments' has multiple paths to parent table 'users'. Using the shortest one: comments.fk_users_userid -> users.__pk__
# /mnt/personal/kolesole/RTGL/rtgl_tasks/base/rtgl_stat_task.py:33: [WARN] Table 'posts' has multiple paths to parent table 'comments'. Using the shortest one: posts.__pk__ -> comments.fk_posts_postid
# SQL query executed in 0.14 seconds
# ------------------ Table ------------------
# DataFrame:
#           fk                                              label
# 2968    6894                                            [20793]
# 3214    7472                                            [45544]
# 385      808  [7694, 5686, 3366, 23199, 23167, 5671, 3840, 1...
# 12715  36127                              [84659, 84648, 84376]
# 12109  33701                                            [80069]
# ...

# %%
from rtgl_tasks.tasks.redelex_tasks import PostPostRelatedStatTask

get_tables(PostPostRelatedStatTask())
# Out:
# SQL query executed in 0.06 seconds
# ------------------ Table ------------------
# DataFrame:
#          fk    label
# 2644  34826  [34826]
# 2227  30143  [30143]
# 6262  76410  [76410]
# 132    2260   [2260]
# 3172  41488  [41488]
# ...     ...      ...
# 7137  85648  [85648]
# 6882  83067  [83067]
# 6116  74684  [74684]
# 6549  79479  [79479]
# 7335  88201  [88201]
#
# [6083 rows x 2 columns]
# Foreign Key Columns to Primary Key Tables: {'fk': 'posts', 'label': 'posts'}
# Primary Key Column: None
# Time Column: None
# -------------------------------------------
# ------------------ Table ------------------
# DataFrame:
#          fk    label
# 6374  77660  [77660]
# 5468  68088  [68088]
# 3561  46721  [46721]
# 4234  54178  [54178]
# 1147  17273  [17273]
# ...     ...      ...
# 1063  16286  [16286]
# 5311  66541  [66541]
# 1267  18954  [18954]
# 6792  82166  [82166]
# 922   14320  [14320]
#
# [760 rows x 2 columns]
# ...

# %%
from rtgl_tasks.tasks.redelex_tasks import UserBadgeTmpTask

get_tables(UserBadgeTmpTask())
# Out:
# SQL query executed in 0.14 seconds
# ------------------ Table ------------------
# DataFrame:
#            fk  timestamp  label
# 0           0 2010-09-04  False
# 1           1 2010-09-04  False
# 2           2 2010-09-04  False
# 3           3 2010-09-04  False
# 4           4 2010-09-04   True
# ...       ...        ...    ...
# 138280  24754 2013-11-30   True
# 138281  24755 2013-11-30   True
# 138282  24756 2013-11-30  False
# 138283  24757 2013-11-30  False
# 138284  24758 2013-11-30   True
#
# [138285 rows x 3 columns]
# Foreign Key Columns to Primary Key Tables: {'fk': 'users'}
# Primary Key Column: None
# Time Column: timestamp
# -------------------------------------------
# SQL query executed in 0.04 seconds
# ------------------ Table ------------------
# DataFrame:
#           fk  timestamp  label
# 0          0 2014-03-01  False
# 1          1 2014-03-01  False
# 2          2 2014-03-01  False
# 3          3 2014-03-01  False
# 4          4 2014-03-01   True
# ...

# %%
from rtgl_tasks.tasks.redelex_tasks import UserEngagementTmpTask

get_tables(UserEngagementTmpTask())
# Out:
# Validation completed with 2 semantic warning(s):
# /mnt/personal/kolesole/RTGL/rtgl_tasks/base/rtgl_tmp_task.py:106: [WARN] Table 'comments' has multiple temporal paths to parent table 'users'. Using the shortest one: comments.fk_users_userid -> users.__pk__
# /mnt/personal/kolesole/RTGL/rtgl_tasks/base/rtgl_tmp_task.py:106: [WARN] Table 'votes' has multiple temporal paths to parent table 'users'. Using the shortest one: votes.fk_users_userid -> users.__pk__
# SQL query executed in 0.25 seconds
# ------------------ Table ------------------
# DataFrame:
#           fk  timestamp  label
# 0          0 2010-09-04  False
# 1          4 2010-09-04   True
# 2          5 2010-09-04   True
# 3          6 2010-09-04   True
# 4          7 2010-09-04   True
# ...      ...        ...    ...
# 85600  24750 2013-11-30  False
# 85601  24753 2013-11-30   True
# 85602  24755 2013-11-30   True
# 85603  24757 2013-11-30  False
# 85604  24758 2013-11-30  False
#
# [85605 rows x 3 columns]
# ...

# %%
from rtgl_tasks.tasks.redelex_tasks import PostVotesTmpTask

get_tables(PostVotesTmpTask())
# Out:
# Validation completed with 1 semantic warning(s):
# /mnt/personal/kolesole/RTGL/rtgl_tasks/base/rtgl_tmp_task.py:106: [WARN] Table 'votes' has multiple temporal paths to parent table 'posts'. Using the shortest one: votes.fk_posts_postid -> posts.__pk__
# SQL query executed in 0.19 seconds
# ------------------ Table ------------------
# DataFrame:
#            fk  timestamp  label
# 0          19 2010-09-04      0
# 1          23 2010-09-04      3
# 2          24 2010-09-04      2
# 3          25 2010-09-04      4
# 4          26 2010-09-04      2
# ...       ...        ...    ...
# 145279  63040 2013-11-30      0
# 145280  63042 2013-11-30      1
# 145281  63043 2013-11-30      0
# 145282  63044 2013-11-30      1
# 145283  63045 2013-11-30      0
#
# [145284 rows x 3 columns]
# Foreign Key Columns to Primary Key Tables: {'fk': 'posts'}
# Primary Key Column: None
# Time Column: timestamp
# -------------------------------------------
# Validation completed with 1 semantic warning(s):
# ...

# %%
from rtgl_tasks.tasks.redelex_tasks import UserPostCommentTmpTask

get_tables(UserPostCommentTmpTask())
# Out:
# Validation completed with 2 semantic warning(s):
# /mnt/personal/kolesole/RTGL/rtgl_tasks/base/rtgl_tmp_task.py:106: [WARN] Table 'comments' has multiple temporal paths to parent table 'users'. Using the shortest one: comments.fk_users_userid -> users.__pk__
# /mnt/personal/kolesole/RTGL/rtgl_tasks/base/rtgl_tmp_task.py:106: [WARN] Table 'posts' has multiple paths to parent table 'comments'. Using the shortest one: posts.__pk__ -> comments.fk_posts_postid
# SQL query executed in 0.18 seconds
# ------------------ Table ------------------
# DataFrame:
#          fk  timestamp                        label
# 0         5 2010-09-04                       [1187]
# 1         7 2010-09-04  [2231, 309, 1187, 1461, 98]
# 2        45 2010-09-04                        [974]
# 3        58 2010-09-04                  [327, 2162]
# 4        60 2010-09-04               [174, 338, 98]
# ...     ...        ...                          ...
# 2525  24564 2013-11-30               [63021, 55968]
# ...

# %%
from rtgl_tasks.tasks.redelex_tasks import PostPostRelatedTmpTask

get_tables(PostPostRelatedTmpTask())
# Out:
# SQL query executed in 0.09 seconds
# ------------------ Table ------------------
# DataFrame:
#         fk  timestamp           label
# 0       48 2010-09-04           [133]
# 1      133 2010-09-04           [356]
# 2      151 2010-09-04            [95]
# 3      206 2010-09-04           [411]
# 4      214 2010-09-04            [32]
# ..     ...        ...             ...
# 684  62567 2013-11-30         [57844]
# 685  62792 2013-11-30         [28080]
# 686  62954 2013-11-30          [2193]
# 687  62994 2013-11-30         [62923]
# 688  63028 2013-11-30  [54665, 20020]
#
# [689 rows x 3 columns]
# Foreign Key Columns to Primary Key Tables: {'fk': 'posts', 'label': 'posts'}
# Primary Key Column: None
# Time Column: timestamp
# -------------------------------------------
# SQL query executed in 0.04 seconds
# ------------------ Table ------------------
# DataFrame:
#        fk  timestamp         label
# 0   11291 2014-03-01        [2361]
# 1   12247 2014-03-01         [364]
# ...

# %% [markdown]
# ## RelBench Datasets

# %% [markdown]
# ### Amazon Dataset

# %%
from rtgl_tasks.tasks.relbench_tasks import UserChurnTmpTask

get_tables(UserChurnTmpTask())
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# SQL query executed in 17.76 seconds
# ------------------ Table ------------------
# DataFrame:
#               fk  timestamp  label
# 0             40 2008-01-10  False
# 1             71 2008-01-10  False
# 2             72 2008-01-10  False
# 3             73 2008-01-10  False
# 4             83 2008-01-10  False
# ...          ...        ...    ...
# 4708378  1850104 2015-07-02  False
# 4708379  1850105 2015-07-02   True
# 4708380  1850109 2015-07-02   True
# 4708381  1850142 2015-07-02   True
# 4708382  1850143 2015-07-02   True
#
# [4708383 rows x 3 columns]
# Foreign Key Columns to Primary Key Tables: {'fk': 'customer'}
# Primary Key Column: None
# Time Column: timestamp
# -------------------------------------------
# SQL query executed in 0.51 seconds
# ------------------ Table ------------------
# DataFrame:
#              fk  timestamp  label
# 0             3 2015-10-01  False
# ...

# %%
from rtgl_tasks.tasks.relbench_tasks import ItemChurnTmpTask

get_tables(ItemChurnTmpTask())
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# SQL query executed in 13.00 seconds
# ------------------ Table ------------------
# DataFrame:
#              fk  timestamp  label
# 0            27 2008-01-10   True
# 1            33 2008-01-10  False
# 2            72 2008-01-10  False
# 3            87 2008-01-10  False
# 4           103 2008-01-10   True
# ...         ...        ...    ...
# 2536009  505991 2015-07-02   True
# 2536010  505992 2015-07-02  False
# 2536011  505994 2015-07-02  False
# 2536012  506000 2015-07-02  False
# 2536013  506002 2015-07-02  False
#
# [2536014 rows x 3 columns]
# Foreign Key Columns to Primary Key Tables: {'fk': 'product'}
# Primary Key Column: None
# Time Column: timestamp
# -------------------------------------------
# SQL query executed in 0.33 seconds
# ------------------ Table ------------------
# DataFrame:
#             fk  timestamp  label
# 0            0 2015-10-01  False
# ...

# %%
from rtgl_tasks.tasks.relbench_tasks import UserLTVTmpTask

get_tables(UserLTVTmpTask())
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# SQL query executed in 18.42 seconds
# ------------------ Table ------------------
# DataFrame:
#               fk  timestamp    label
# 0             40 2008-01-10  1397.63
# 1             71 2008-01-10   137.11
# 2             72 2008-01-10   370.95
# 3             73 2008-01-10   114.44
# 4             83 2008-01-10   199.71
# ...          ...        ...      ...
# 4708378  1850104 2015-07-02    65.96
# 4708379  1850105 2015-07-02     0.00
# 4708380  1850109 2015-07-02     0.00
# 4708381  1850142 2015-07-02     0.00
# 4708382  1850143 2015-07-02     0.00
#
# [4708383 rows x 3 columns]
# Foreign Key Columns to Primary Key Tables: {'fk': 'customer'}
# Primary Key Column: None
# Time Column: timestamp
# -------------------------------------------
# SQL query executed in 0.78 seconds
# ------------------ Table ------------------
# DataFrame:
#              fk  timestamp  label
# ...

# %%
from rtgl_tasks.tasks.relbench_tasks import UserItemPurchaseTmpTask

get_tables(UserItemPurchaseTmpTask())
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# SQL query executed in 19.66 seconds
# ------------------ Table ------------------
# DataFrame:
#               fk  timestamp                                              label
# 0              5 2008-01-10                                           [269902]
# 1             38 2008-01-10                                           [152157]
# 2             40 2008-01-10  [78406, 21568, 122585, 503881, 59893, 39588, 8...
# 3             42 2008-01-10                                           [149041]
# 4             71 2008-01-10  [28257, 34742, 33923, 69352, 145410, 97825, 81...
# ...          ...        ...                                                ...
# 5112798  1850080 2015-07-02                                           [321814]
# 5112799  1850086 2015-07-02                                           [504372]
# ...

# %%
from rtgl_tasks.tasks.relbench_tasks import UserItemRateTmpTask

get_tables(UserItemRateTmpTask())
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# SQL query executed in 14.91 seconds
# ------------------ Table ------------------
# DataFrame:
#               fk  timestamp                                              label
# 0              5 2008-01-10                                           [269902]
# 1             38 2008-01-10                                           [152157]
# 2             40 2008-01-10  [78406, 38153, 265096, 406986, 99943, 26181, 1...
# 3             71 2008-01-10                                     [28257, 34742]
# 4             72 2008-01-10       [29643, 73671, 59258, 147964, 147763, 39387]
# ...          ...        ...                                                ...
# 3667152  1850058 2015-07-02                                           [337140]
# 3667153  1850067 2015-07-02                                   [338506, 346119]
# ...

# %%
from rtgl_tasks.tasks.relbench_tasks import ItemLTVTmpTask

get_tables(ItemLTVTmpTask())
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# SQL query executed in 13.25 seconds
# ------------------ Table ------------------
# DataFrame:
#              fk  timestamp    label
# 0             9 2008-01-10    16.04
# 1            12 2008-01-10    29.00
# 2            15 2008-01-10    96.42
# 3            16 2008-01-10    10.80
# 4            19 2008-01-10    13.86
# ...         ...        ...      ...
# 2707674  505996 2015-07-02    42.70
# 2707675  505998 2015-07-02    35.38
# 2707676  505999 2015-07-02    18.53
# 2707677  506000 2015-07-02  1929.92
# 2707678  506002 2015-07-02    39.64
#
# [2707679 rows x 3 columns]
# Foreign Key Columns to Primary Key Tables: {'fk': 'product'}
# Primary Key Column: None
# Time Column: timestamp
# -------------------------------------------
# SQL query executed in 0.35 seconds
# ------------------ Table ------------------
# DataFrame:
#             fk  timestamp    label
# ...

# %%
from rtgl_tasks.tasks.relbench_tasks import ItemLTVTmpTaskInjection

get_tables(ItemLTVTmpTaskInjection())
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# SQL query executed in 13.41 seconds
# ------------------ Table ------------------
# DataFrame:
#              fk  timestamp    label
# 0             9 2008-01-10    16.04
# 1            12 2008-01-10    29.00
# 2            15 2008-01-10    96.42
# 3            16 2008-01-10    10.80
# 4            19 2008-01-10    13.86
# ...         ...        ...      ...
# 2707674  505996 2015-07-02    42.70
# 2707675  505998 2015-07-02    35.38
# 2707676  505999 2015-07-02    18.53
# 2707677  506000 2015-07-02  1929.92
# 2707678  506002 2015-07-02    39.64
#
# [2707679 rows x 3 columns]
# Foreign Key Columns to Primary Key Tables: {'fk': 'product'}
# Primary Key Column: None
# Time Column: timestamp
# -------------------------------------------
# SQL query executed in 0.46 seconds
# ------------------ Table ------------------
# DataFrame:
#             fk  timestamp    label
# ...

# %%
from rtgl_tasks.tasks.relbench_tasks import UserItemReviewTmpTaskInjection

get_tables(UserItemReviewTmpTaskInjection())
# Out:
# Validation completed with 1 semantic warning(s):
# /mnt/personal/kolesole/RTGL/rtgl_tasks/base/rtgl_tmp_task.py:106: [WARN] Table 'filtered_review' has multiple temporal paths to parent table 'customer'. Using the shortest one: filtered_review.customer_id -> customer.customer_id
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# SQL query executed in 12.53 seconds
# ------------------ Table ------------------
# DataFrame:
#               fk  timestamp                                              label
# 0              5 2008-01-10                                           [269902]
# 1             38 2008-01-10                                           [152157]
# 2             40 2008-01-10  [53334, 97117, 503881, 26181, 59893, 39588, 80...
# 3             42 2008-01-10                                           [149041]
# 4             71 2008-01-10  [145410, 97825, 262806, 8181, 79062, 28257, 34...
# ...

# %% [markdown]
# ### Arxiv Dataset

# %%
from rtgl_tasks.tasks.relbench_tasks import PaperCitationTmpTask

get_tables(PaperCitationTmpTask())
# Out:
# SQL query executed in 0.36 seconds
# ------------------ Table ------------------
# DataFrame:
#             fk  timestamp  label
# 0            0 2018-01-06  False
# 1            1 2018-01-06  False
# 2            2 2018-01-06  False
# 3            3 2018-01-06  False
# 4            4 2018-01-06  False
# ...        ...        ...    ...
# 534228  136178 2021-07-03  False
# 534229  136179 2021-07-03  False
# 534230  136180 2021-07-03  False
# 534231  136181 2021-07-03  False
# 534232  136182 2021-07-03  False
#
# [534233 rows x 3 columns]
# Foreign Key Columns to Primary Key Tables: {'fk': 'papers'}
# Primary Key Column: None
# Time Column: timestamp
# -------------------------------------------
# SQL query executed in 0.10 seconds
# ------------------ Table ------------------
# DataFrame:
#             fk  timestamp  label
# 0            0 2022-01-01  False
# 1            1 2022-01-01  False
# 2            2 2022-01-01   True
# 3            3 2022-01-01  False
# ...

# %%
from rtgl_tasks.tasks.relbench_tasks import PaperCitationTmpTaskInjection

get_tables(PaperCitationTmpTaskInjection())
# Out:
# SQL query executed in 0.36 seconds
# ------------------ Table ------------------
# DataFrame:
#             fk  timestamp  label
# 0            0 2018-01-06  False
# 1            1 2018-01-06  False
# 2            2 2018-01-06  False
# 3            3 2018-01-06  False
# 4            4 2018-01-06  False
# ...        ...        ...    ...
# 534228  136178 2021-07-03  False
# 534229  136179 2021-07-03  False
# 534230  136180 2021-07-03  False
# 534231  136181 2021-07-03  False
# 534232  136182 2021-07-03  False
#
# [534233 rows x 3 columns]
# Foreign Key Columns to Primary Key Tables: {'fk': 'papers'}
# Primary Key Column: None
# Time Column: timestamp
# -------------------------------------------
# SQL query executed in 0.10 seconds
# ------------------ Table ------------------
# DataFrame:
#             fk  timestamp  label
# 0            0 2022-01-01  False
# 1            1 2022-01-01  False
# 2            2 2022-01-01   True
# 3            3 2022-01-01  False
# ...

# %% [markdown]
# ### F1 Dataset

# %%
from rtgl_tasks.tasks.relbench_tasks import DriverDNFTmpTask

get_tables(DriverDNFTmpTask())
# Out:
# Validation completed with 1 semantic warning(s):
# /mnt/personal/kolesole/RTGL/rtgl_tasks/base/rtgl_tmp_task.py:106: [WARN] Table 'results' has multiple temporal paths to parent table 'drivers'. Using the shortest one: results.driverid -> drivers.driverid
# SQL query executed in 0.65 seconds
# ------------------ Table ------------------
# DataFrame:
#         fk  timestamp  label
# 0      579 1950-05-20   True
# 1      589 1950-05-20   True
# 2      619 1950-05-20   True
# 3      627 1950-05-20   True
# 4      640 1950-05-20   True
# ...    ...        ...    ...
# 10384   34 2004-10-03   True
# 10385   40 2004-10-03   True
# 10386   43 2004-10-03   True
# 10387   45 2004-10-03   True
# 10388   46 2004-10-03   True
#
# [10389 rows x 3 columns]
# Foreign Key Columns to Primary Key Tables: {'fk': 'drivers'}
# Primary Key Column: None
# Time Column: timestamp
# -------------------------------------------
# Validation completed with 1 semantic warning(s):
# ...

# %%
from rtgl_tasks.tasks.relbench_tasks import DriverTop3TmpTask

get_tables(DriverTop3TmpTask())
# Out:
# Validation completed with 1 semantic warning(s):
# /mnt/personal/kolesole/RTGL/rtgl_tasks/base/rtgl_tmp_task.py:106: [WARN] Table 'qualifying' has multiple temporal paths to parent table 'drivers'. Using the shortest one: qualifying.driverid -> drivers.driverid
# SQL query executed in 0.31 seconds
# ------------------ Table ------------------
# DataFrame:
#       fk  timestamp  label
# 0     21 1994-02-28  False
# 1     29 1994-02-28   True
# 2     43 1994-02-28  False
# 3     48 1994-02-28  False
# 4     49 1994-02-28  False
# ...   ..        ...    ...
# 1348  34 2004-10-03  False
# 1349  40 2004-10-03  False
# 1350  43 2004-10-03  False
# 1351  45 2004-10-03  False
# 1352  46 2004-10-03  False
#
# [1353 rows x 3 columns]
# Foreign Key Columns to Primary Key Tables: {'fk': 'drivers'}
# Primary Key Column: None
# Time Column: timestamp
# -------------------------------------------
# Validation completed with 1 semantic warning(s):
# ...

# %%
from rtgl_tasks.tasks.relbench_tasks import DriverPositionTmpTask

get_tables(DriverPositionTmpTask())
# Out:
# Validation completed with 1 semantic warning(s):
# /mnt/personal/kolesole/RTGL/rtgl_tasks/base/rtgl_tmp_task.py:106: [WARN] Table 'results' has multiple temporal paths to parent table 'drivers'. Using the shortest one: results.driverid -> drivers.driverid
# SQL query executed in 0.33 seconds
# ------------------ Table ------------------
# DataFrame:
#        fk  timestamp  label
# 0     498 1950-06-19   18.0
# 1     579 1950-06-19    1.0
# 2     589 1950-06-19   15.0
# 3     626 1950-06-19    4.0
# 4     627 1950-06-19    9.0
# ...   ...        ...    ...
# 7448   41 2004-09-03    7.0
# 7449   43 2004-09-03   16.0
# 7450   44 2004-09-03   17.0
# 7451   45 2004-09-03   17.0
# 7452   46 2004-09-03   16.0
#
# [7453 rows x 3 columns]
# Foreign Key Columns to Primary Key Tables: {'fk': 'drivers'}
# Primary Key Column: None
# Time Column: timestamp
# -------------------------------------------
# Validation completed with 1 semantic warning(s):
# ...

# %%
from rtgl_tasks.tasks.relbench_tasks import DriverCircuitCompleteTmpTask

get_tables(DriverCircuitCompleteTmpTask())
# Out:
# SQL query executed in 0.05 seconds
# ------------------ Table ------------------
# DataFrame:
#        fk  timestamp                                              label
# 0     426 1951-01-15                                   [54, 19, 13, 66]
# 1     428 1951-01-15                                               [12]
# 2     448 1951-01-15                                               [18]
# 3     475 1951-01-15                                               [65]
# 4     498 1951-01-15                            [65, 54, 8, 19, 13, 66]
# ...   ...        ...                                                ...
# 2644   43 2004-01-02  [0, 16, 5, 9, 20, 3, 6, 12, 2, 18, 10, 19, 7, ...
# 2645   44 2004-01-02   [0, 5, 9, 20, 3, 12, 2, 18, 10, 19, 7, 8, 13, 1]
# 2646   45 2004-01-02  [20, 3, 6, 12, 5, 9, 17, 0, 16, 1, 21, 19, 7, ...
# 2647   46 2004-01-02  [20, 3, 6, 12, 5, 9, 17, 0, 16, 1, 21, 19, 7, ...
# 2648   47 2004-01-02                                             [7, 8]
#
# ...

# %%
from rtgl_tasks.tasks.relbench_tasks import DriverCircuitCompleteTmpTaskInjection

get_tables(DriverCircuitCompleteTmpTaskInjection())
# Out:
# Validation completed with 1 semantic warning(s):
# /mnt/personal/kolesole/RTGL/rtgl_tasks/base/rtgl_tmp_task.py:106: [WARN] Table 'circuits_drivers' has multiple temporal paths to parent table 'drivers'. Using the shortest one: circuits_drivers.driverid -> drivers.driverid
# SQL query executed in 0.09 seconds
# ------------------ Table ------------------
# DataFrame:
#        fk  timestamp                                              label
# 0     426 1951-01-15                                   [54, 66, 13, 19]
# 1     428 1951-01-15                                               [12]
# 2     448 1951-01-15                                               [18]
# 3     475 1951-01-15                                               [65]
# 4     498 1951-01-15                            [54, 65, 66, 13, 19, 8]
# ...   ...        ...                                                ...
# 2644   43 2004-01-02  [9, 5, 10, 18, 2, 16, 0, 21, 1, 13, 8, 7, 19, ...
# ...

# %% [markdown]
# ### Stack Dataset

# %%
from rtgl_tasks.tasks.relbench_tasks import UserEngagementTmpTask

get_tables(UserEngagementTmpTask())
# Out:
# Validation completed with 3 semantic warning(s):
# /mnt/personal/kolesole/RTGL/rtgl_tasks/base/rtgl_tmp_task.py:106: [WARN] Table 'comments' has multiple temporal paths to parent table 'users'. Using the shortest one: comments.userid -> users.id
# /mnt/personal/kolesole/RTGL/rtgl_tasks/base/rtgl_tmp_task.py:106: [WARN] Table 'posts' has multiple temporal paths to parent table 'users'. Using the shortest one: posts.owneruserid -> users.id
# /mnt/personal/kolesole/RTGL/rtgl_tasks/base/rtgl_tmp_task.py:106: [WARN] Table 'votes' has multiple temporal paths to parent table 'users'. Using the shortest one: votes.userid -> users.id
# SQL query executed in 2.02 seconds
# ------------------ Table ------------------
# DataFrame:
#              fk  timestamp  label
# 0             0 2010-10-14  False
# 1             4 2010-10-14   True
# 2             5 2010-10-14   True
# 3             6 2010-10-14  False
# 4             7 2010-10-14   True
# ...         ...        ...    ...
# ...

# %%
from rtgl_tasks.tasks.relbench_tasks import UserBadgeTmpTask

get_tables(UserBadgeTmpTask())
# Out:
# SQL query executed in 0.77 seconds
# ------------------ Table ------------------
# DataFrame:
#              fk  timestamp  label
# 0             0 2010-10-14  False
# 1             1 2010-10-14   True
# 2             2 2010-10-14  False
# 3             3 2010-10-14  False
# 4             4 2010-10-14   True
# ...         ...        ...    ...
# 3386271  239940 2020-07-02  False
# 3386272  239941 2020-07-02  False
# 3386273  239942 2020-07-02  False
# 3386274  239943 2020-07-02  False
# 3386275  239944 2020-07-02   True
#
# [3386276 rows x 3 columns]
# Foreign Key Columns to Primary Key Tables: {'fk': 'users'}
# Primary Key Column: None
# Time Column: timestamp
# -------------------------------------------
# SQL query executed in 0.13 seconds
# ------------------ Table ------------------
# DataFrame:
#             fk  timestamp  label
# 0            0 2020-10-01  False
# 1            1 2020-10-01  False
# 2            2 2020-10-01  False
# 3            3 2020-10-01  False
# ...

# %%
from rtgl_tasks.tasks.relbench_tasks import PostVotesTmpTask

get_tables(PostVotesTmpTask())
# Out:
# Validation completed with 1 semantic warning(s):
# /mnt/personal/kolesole/RTGL/rtgl_tasks/base/rtgl_tmp_task.py:106: [WARN] Table 'votes' has multiple temporal paths to parent table 'posts'. Using the shortest one: votes.postid -> posts.id
# SQL query executed in 1.03 seconds
# ------------------ Table ------------------
# DataFrame:
#              fk  timestamp  label
# 0             0 2009-04-16      0
# 1             0 2009-07-16      0
# 2             0 2009-10-15      0
# 3             0 2010-01-14      0
# 4             0 2010-04-15      0
# ...         ...        ...    ...
# 2454033  315139 2020-07-02      0
# 2454034  315140 2020-07-02      0
# 2454035  315142 2020-07-02      0
# 2454036  315144 2020-07-02      0
# 2454037  315145 2020-07-02      0
#
# [2454038 rows x 3 columns]
# Foreign Key Columns to Primary Key Tables: {'fk': 'posts'}
# Primary Key Column: None
# Time Column: timestamp
# -------------------------------------------
# ...

# %%
from rtgl_tasks.tasks.relbench_tasks import UserPostCommentTmpTask

get_tables(UserPostCommentTmpTask())
# Out:
# Validation completed with 2 semantic warning(s):
# /mnt/personal/kolesole/RTGL/rtgl_tasks/base/rtgl_tmp_task.py:106: [WARN] Table 'comments' has multiple temporal paths to parent table 'users'. Using the shortest one: comments.userid -> users.id
# /mnt/personal/kolesole/RTGL/rtgl_tasks/base/rtgl_tmp_task.py:106: [WARN] Table 'posts' has multiple paths to parent table 'comments'. Using the shortest one: posts.id -> comments.postid
# SQL query executed in 1.23 seconds
# ------------------ Table ------------------
# DataFrame:
#            fk  timestamp                     label
# 0           4 2010-10-14                    [2457]
# 1           5 2010-10-14                    [1173]
# 2           7 2010-10-14                    [1173]
# 3          46 2010-10-14                     [577]
# 4          58 2010-10-14               [321, 3226]
# ...       ...        ...                       ...
# 18652  239691 2020-07-02  [314965, 314753, 314966]
# ...

# %%
from rtgl_tasks.tasks.relbench_tasks import PostPostRelatedTmpTask

get_tables(PostPostRelatedTmpTask())
# Out:
# SQL query executed in 0.51 seconds
# ------------------ Table ------------------
# DataFrame:
#           fk  timestamp             label
# 0        128 2010-10-14             [348]
# 1        486 2010-10-14      [3000, 2953]
# 2        930 2010-10-14              [29]
# 3        963 2010-10-14            [3269]
# 4       1150 2010-10-14             [486]
# ...      ...        ...               ...
# 5850  315039 2020-07-02  [159209, 168163]
# 5851  315054 2020-07-02          [244965]
# 5852  315060 2020-07-02           [98531]
# 5853  315083 2020-07-02           [47666]
# 5854  315107 2020-07-02           [29372]
#
# [5855 rows x 3 columns]
# Foreign Key Columns to Primary Key Tables: {'fk': 'posts', 'label': 'posts'}
# Primary Key Column: None
# Time Column: timestamp
# -------------------------------------------
# SQL query executed in 0.07 seconds
# ------------------ Table ------------------
# DataFrame:
#          fk  timestamp                     label
# ...
